# %% [markdown]
# We are currently working in the following directory:

# %%
# !pwd
# Out:
# /c/Users/tinaf/Desktop/ubc_data_science_toolbox/jupyterlab_practice

# %% [markdown]
# To time how long it takes to run a Python cell, we could use the `timeit` command inside a cell as is shown below:
#
# ```python
# %%timeit
# for i in range(1_000_000):
#     i**2
# ```

# %%
# Export this notebook to HTML file with no code cell
# !jupyter nbconvert question12.ipynb \
    --to html \
    --output=output-filename.html \
    --no-input
# Out:
# [NbConvertApp] Converting notebook question12.ipynb to html
# [NbConvertApp] Writing 270921 bytes to output-filename.html
